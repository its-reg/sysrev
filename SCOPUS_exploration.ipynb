# %% [markdown]
# # SCOPUS

# %% [markdown]
# Requested an API Key from the Elsevier Developer Portal <https://dev.elsevier.com/apikey/manage>. <br>
# Stored in config. Install pybliometrics.

# %% [markdown]
# ## Imports

# %%
# %pip install pybliometrics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pybliometrics
pybliometrics.init() # Uses saved API key in my config file

# %%
from pybliometrics.scopus import general
import pandas as pd

# %% [markdown]
# ## Search
